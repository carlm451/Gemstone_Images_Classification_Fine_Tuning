# %% [markdown]
# <a href="https://colab.research.google.com/github/carlm451/Gemstone_Images_Classification_Fine_Tuning/blob/main/Gemstones_Fine_Tuning_Test2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers

import numpy as np

import os
import matplotlib.pyplot as plt
from random import shuffle 

#will use efficientnet ...hope it will be a pretrained model we can fine-tune easily 
from tensorflow.keras.applications.densenet import DenseNet121

# %%
# pulling gemstones data from kaggle
#!pip install kaggle

# !mkdir ~/.kaggle

#need a kaggle API key kaggle.json
# !mv kaggle.json ~/.kaggle
! chmod 600 ~/.kaggle/kaggle.json

# !kaggle datasets download lsind18/gemstones-images
# Out:
# Downloading gemstones-images.zip to /content
# 100% 55.2M/55.2M [00:04<00:00, 18.2MB/s]
# 100% 55.2M/55.2M [00:04<00:00, 12.5MB/s]

# %%
# !unzip gemstones-images.zip &> /dev/null  #suppress terminal output when unzipping images
# !ls
# Out:
# gemstones-images.zip  sample_data  test  train

# %%
#going to split of some of the training data for a validation data set
# !mkdir val

# %%
import os

data_dir = '/content'

train_dir = os.path.join(data_dir,'train')

val_dir = os.path.join(data_dir,'val')

test_dir = os.path.join(data_dir,'test')

def count_img_samples(directory):
    
    count = 0
    
    for i,gem_type in enumerate(os.listdir(directory)):
        
        gem_dir = os.path.join(directory,gem_type)
    
        img_list = os.listdir(gem_dir)

        #print(f' dir {gem_dir} has {len(img_list)} images')

        count += len(img_list)
    
    return count

n_train = count_img_samples(train_dir)
n_test = count_img_samples(test_dir)
n_val = count_img_samples(val_dir)

print(f'{n_train=}, {n_val=}, {n_test=}')
# Out:
# n_train=2856, n_val=0, n_test=363

# %%
from random import shuffle

def partition_val_data(train_dir,val_dir,val_split=0.1):
    
    for gem_type in os.listdir(train_dir):
        
        train_gem_dir = os.path.join(train_dir,gem_type)
        
        img_list = os.listdir(train_gem_dir)
        
        shuffle(img_list)
        
        n_samples = round(len(img_list)*val_split)
        
        val_img_list = img_list[:n_samples] # take n_samples random images to move
        
        val_gem_dir = os.path.join(val_dir,gem_type)
        
        if not os.path.exists(val_gem_dir):
            
            os.mkdir(val_gem_dir)
            
            for gem_img in val_img_list:
                
                original_path = os.path.join(train_gem_dir,gem_img)
                
                destination_path = os.path.join(val_gem_dir,gem_img)
                
                os.rename(original_path,destination_path)
        
            print(f'Moved {len(os.listdir(val_gem_dir))} training images from to {val_gem_dir}')
            
        else:
            
            print(f'Val dir {val_gem_dir} has {len(os.listdir(val_gem_dir))} images')

# %%
val_split=0.15  # move 15% train to use for validation

partition_val_data(train_dir,val_dir,val_split)
# Out:
# Moved 4 training images from to /content/val/Spessartite
# Moved 5 training images from to /content/val/Chrysoberyl
# Moved 5 training images from to /content/val/Opal
# Moved 6 training images from to /content/val/Citrine
# Moved 5 training images from to /content/val/Iolite
# Moved 4 training images from to /content/val/Zoisite
# Moved 5 training images from to /content/val/Pearl
# Moved 4 training images from to /content/val/Chrysoprase
# Moved 5 training images from to /content/val/Amber
# Moved 5 training images from to /content/val/Turquoise
# Moved 5 training images from to /content/val/Danburite
# Moved 5 training images from to /content/val/Spodumene
# Moved 5 training images from to /content/val/Sapphire Blue
# Moved 5 training images from to /content/val/Almandine
# Moved 5 training images from to /content/val/Andradite
# Moved 5 training images from to /content/val/Diaspore
# Moved 7 training images from to /content/val/Aventurine Green
# Moved 5 training images from to /content/val/Kunzite
# Moved 4 training images from to /content/val/Scapolite
# Moved 6 training images from to /content/val/Labradorite
# Moved 4 training images from to /content/val/Variscite
# Moved 5 training images from to /content/val/Sapphire Yellow
# Moved 5 training images from to /content/val/Chrysocolla
# Moved 5 training images from to /content/val/Fluorite
# Moved 5 training images from to /content/val/Chrome Diopside
# Moved 4 training images from to /content/val/Malachite
# Moved 4 training images from to /content/val/Spinel
# Moved 5 training images from to /content/val/Andalusite
# Moved 5 training images from to /content/val/Coral
# Moved 5 training images from to /content/val/Quartz Rose
# Moved 5 training images from to /content/val/Tsavorite
# Moved 6 training images from to /content/val/Blue Lace Agate
# Moved 5 training images from to /content/val/Tanzanite
# Moved 4 training images from to /content/val/Hiddenite
# Moved 4 training images from to /content/val/Sapphire Pink
# Moved 5 training images from to /content/val/Aventurine Yellow
# Moved 4 training images from to /content/val/Larimar
# Moved 5 training images from to /content/val/Quartz Lemon
# Moved 5 training images from to /content/val/Emerald
# Moved 5 training images from to /content/val/Diamond
# Moved 5 training images from to /content/val/Rhodolite
# Moved 5 training images from to /content/val/Bloodstone
# Moved 5 training images from to /content/val/Dumortierite
# Moved 5 training images from to /content/val/Amazonite
# Moved 4 training images from to /content/val/Onyx Red
# Moved 4 training images from to /content/val/Onyx Black
# Moved 5 training images from to /content/val/Pyrope
# Moved 4 training images from to /content/val/Chalcedony
# Moved 5 training images from to /content/val/Carnelian
# Moved 5 training images from to /content/val/Rhodonite
# Moved 5 training images from to /content/val/Ruby
# Moved 5 training images from to /content/val/Aquamarine
# Moved 5 training images from to /content/val/Amethyst
# Moved 4 training images from to /content/val/Sunstone
# Moved 5 training images from to /content/val/Moonstone
# Moved 6 training images from to /content/val/Tourmaline
# Moved 4 training images from to /content/val/Sphene
# Moved 5 training images from to /content/val/Bixbite
# Moved 6 training images from to /content/val/Prehnite
# Moved 4 training images from to /content/val/Onyx Green
# Moved 4 training images from to /content/val/Jade
# Moved 5 training images from to /content/val/Lapis Lazuli
# Moved 4 training images from to /content/val/Rhodochrosite
# Moved 4 training images from to /content/val/Grossular
# Moved 5 training images from to /content/val/Zircon
# Moved 5 training images from to /content/val/Sapphire Purple
# Moved 6 training images from to /content/val/Peridot
# Moved 4 training images from to /content/val/Serpentine
# Moved 5 training images from to /content/val/Ametrine
# Moved 4 training images from to /content/val/Kyanite
# Moved 5 training images from to /content/val/Sodalite
# Moved 6 training images from to /content/val/Quartz Rutilated
# Moved 5 training images from to /content/val/Morganite
# Moved 5 training images from to /content/val/Alexandrite
# Moved 5 training images from to /content/val/Garnet Red
# Moved 5 training images from to /content/val/Goshenite
# Moved 6 training images from to /content/val/Pyrite
# Moved 5 training images from to /content/val/Topaz
# Moved 5 training images from to /content/val/Quartz Beer
# Moved 5 training images from to /content/val/Cats Eye
# Moved 4 training images from to /content/val/Chalcedony Blue
# Moved 5 training images from to /content/val/Benitoite
# Moved 5 training images from to /content/val/Beryl Golden
# Moved 4 training images from to /content/val/Hessonite
# Moved 4 training images from to /content/val/Quartz Smoky
# Moved 6 training images from to /content/val/Tigers Eye
# Moved 5 training images from to /content/val/Jasper

# %%
from tensorflow.keras.utils import load_img, img_to_array

def get_img_array(directory,gem_type):
    
    gem_dir = os.path.join(directory,gem_type)
    
    img_list = os.listdir(gem_dir)
    
    #shuffle(img_list)
    
    img_path = os.path.join(gem_dir,img_list[0])
    
    img = load_img(img_path)
    
    x = img_to_array(img) / 255.
    
    return x

def get_img_array_resized(directory,gem_type):
    
    gem_dir = os.path.join(directory,gem_type)
    
    img_list = os.listdir(gem_dir)
    
    #shuffle(img_list)
    
    img_path = os.path.join(gem_dir,img_list[0])
    
    img = load_img(img_path,target_size=(224,224),keep_aspect_ratio=False)
    
    x = img_to_array(img) / 255.
    
    return x

# %%
# !ls val

gem_types_list = os.listdir(val_dir)

n_classes = len(gem_types_list)

print(f'{n_classes} classes of gemstone')
# Out:
#  Alexandrite	      Chrysocolla     Larimar		 'Sapphire Blue'
#  Almandine	      Chrysoprase     Malachite		 'Sapphire Pink'
#  Amazonite	      Citrine	      Moonstone		 'Sapphire Purple'
#  Amber		      Coral	      Morganite		 'Sapphire Yellow'
#  Amethyst	      Danburite      'Onyx Black'	  Scapolite
#  Ametrine	      Diamond	     'Onyx Green'	  Serpentine
#  Andalusite	      Diaspore	     'Onyx Red'		  Sodalite
#  Andradite	      Dumortierite    Opal		  Spessartite
#  Aquamarine	      Emerald	      Pearl		  Sphene
# 'Aventurine Green'    Fluorite	      Peridot		  Spinel
# 'Aventurine Yellow'  'Garnet Red'     Prehnite		  Spodumene
#  Benitoite	      Goshenite       Pyrite		  Sunstone
# 'Beryl Golden'	      Grossular       Pyrope		  Tanzanite
#  Bixbite	      Hessonite      'Quartz Beer'	 'Tigers Eye'
#  Bloodstone	      Hiddenite      'Quartz Lemon'	  Topaz
# 'Blue Lace Agate'     Iolite	     'Quartz Rose'	  Tourmaline
#  Carnelian	      Jade	     'Quartz Rutilated'   Tsavorite
# 'Cats Eye'	      Jasper	     'Quartz Smoky'	  Turquoise
#  Chalcedony	      Kunzite	      Rhodochrosite	  Variscite
# 'Chalcedony Blue'     Kyanite	      Rhodolite		  Zircon
# 'Chrome Diopside'     Labradorite     Rhodonite		  Zoisite
#  Chrysoberyl	     'Lapis Lazuli'   Ruby
# 87 classes of gemstone

# %%
import matplotlib.pyplot as plt

shuffle(gem_types_list)

fig,axes=plt.subplots(6,6,figsize=(9,9))

count=0

for i in range(6):
  for j in range(6):

      gem_type=gem_types_list[count]

      sample_x = get_img_array(train_dir,gem_type)
      sample_x_resized = get_img_array_resized(train_dir,gem_type)

      axes[i,j].imshow(sample_x_resized)
      axes[i,j].set_axis_off()
      axes[i,j].set_title(f'{gem_type}')
      count+=1

plt.show()

# %%
# generators to stream images for training/validation
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale = 1.0/255.,
                                   rotation_range=90,
                                   width_shift_range=0.4,
                                   height_shift_range=0.4,
                                   zoom_range=0.5,
                                   horizontal_flip=True,
                                   vertical_flip=True,
                                  )

val_datagen  = ImageDataGenerator( rescale = 1.0/255.)

train_generator = train_datagen.flow_from_directory(train_dir,
                                                    batch_size=64,
                                                    class_mode='categorical',
                                                    target_size=(224, 224),
                                                    keep_aspect_ratio=False,
                                                    classes=gem_types_list) 

val_generator = val_datagen.flow_from_directory(val_dir,
                                                    batch_size=64,
                                                    class_mode='categorical',
                                                    target_size=(224,224),
                                                    keep_aspect_ratio=False,
                                                    classes=gem_types_list)
# Out:
# Found 2434 images belonging to 87 classes.
# Found 422 images belonging to 87 classes.

# %%
def get_uncompiled_model(n_classes, model_name,fine_tune=0):

    tf.keras.backend.clear_session()

    pretrained = DenseNet121(include_top=False, pooling='avg',input_shape=(224,224,3))

    if fine_tune > 0:
        for layer in pretrained.layers[:-fine_tune]:
            layer.trainable = False
    else:
        pretrained.trainable=False #freezes all children layers 

    inputs=tf.keras.layers.Input(shape=(224,224,3))

    x=pretrained(inputs,training=False)   #this is important for behavior of batch norm layers when fine-tuning

    x = tf.keras.layers.Dense(512)(x)

    x = tf.keras.layers.Dropout(0.2)(x)

    x = tf.keras.layers.Dense(n_classes)(x)  # make sure to use from_logits=True in loss later on

    model = tf.keras.Model(inputs=inputs,outputs=x)
    
    return model

# %%
model_1 = get_uncompiled_model(n_classes,model_name='mobilenetV2_frozen')
    
model_1.summary()

#checking that the input size is correct, should be (224,224,3)
model_1.input
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  densenet121 (Functional)    (None, 1024)              7037504
#
#  dense (Dense)               (None, 512)               524800
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 87)                44631
#
# =================================================================
# Total params: 7,606,935
# Trainable params: 569,431
# Non-trainable params: 7,037,504
# _________________________________________________________________
# <KerasTensor: shape=(None, 224, 224, 3) dtype=float32 (created by layer 'input_2')>

# %%
model_1.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005),
              loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
              metrics = [tf.keras.metrics.CategoricalAccuracy()])

# %%
# !rm -r training_1

# !mkdir training_1

checkpoint_path = "training_1/cp-{epoch:04d}.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

N_EPOCHS=20

# Create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1,
                                                 save_freq='epoch')

history_1 = model_1.fit(
            train_generator,
            epochs=N_EPOCHS,
            validation_data=val_generator,
            verbose=1,
            callbacks=[cp_callback]
            )
# Out:
# Epoch 1/20
# 39/39 [==============================] - ETA: 0s - loss: 4.2314 - categorical_accuracy: 0.0809
# Epoch 1: saving model to training_1/cp-0001.ckpt
# 39/39 [==============================] - 50s 1s/step - loss: 4.2314 - categorical_accuracy: 0.0809 - val_loss: 3.1884 - val_categorical_accuracy: 0.2654
# Epoch 2/20
# 39/39 [==============================] - ETA: 0s - loss: 2.8577 - categorical_accuracy: 0.3172
# Epoch 2: saving model to training_1/cp-0002.ckpt
# 39/39 [==============================] - 40s 1s/step - loss: 2.8577 - categorical_accuracy: 0.3172 - val_loss: 2.3652 - val_categorical_accuracy: 0.4123
# Epoch 3/20
# 39/39 [==============================] - ETA: 0s - loss: 2.1946 - categorical_accuracy: 0.4589
# Epoch 3: saving model to training_1/cp-0003.ckpt
# 39/39 [==============================] - 40s 1s/step - loss: 2.1946 - categorical_accuracy: 0.4589 - val_loss: 1.9662 - val_categorical_accuracy: 0.5237
# Epoch 4/20
# 39/39 [==============================] - ETA: 0s - loss: 1.8429 - categorical_accuracy: 0.5296
# Epoch 4: saving model to training_1/cp-0004.ckpt
# 39/39 [==============================] - 40s 1s/step - loss: 1.8429 - categorical_accuracy: 0.5296 - val_loss: 1.8007 - val_categorical_accuracy: 0.5213
# Epoch 5/20
# 39/39 [==============================] - ETA: 0s - loss: 1.6284 - categorical_accuracy: 0.5624
# Epoch 5: saving model to training_1/cp-0005.ckpt
# 39/39 [==============================] - 40s 1s/step - loss: 1.6284 - categorical_accuracy: 0.5624 - val_loss: 1.6208 - val_categorical_accuracy: 0.5735
# Epoch 6/20
# 38/39 [============================>.] - ETA: 0s - loss: 1.4292 - categorical_accuracy: 0.6151
# Epoch 6: saving model to training_1/cp-0006.ckpt
# 39/39 [==============================] - 41s 1s/step - loss: 1.4297 - categorical_accuracy: 0.6150 - val_loss: 1.4728 - val_categorical_accuracy: 0.5972
# Epoch 7/20
# 39/39 [==============================] - ETA: 0s - loss: 1.3048 - categorical_accuracy: 0.6397
# Epoch 7: saving model to training_1/cp-0007.ckpt
# 39/39 [==============================] - 40s 1s/step - loss: 1.3048 - categorical_accuracy: 0.6397 - val_loss: 1.3860 - val_categorical_accuracy: 0.6398
# Epoch 8/20
# 39/39 [==============================] - ETA: 0s - loss: 1.2068 - categorical_accuracy: 0.6647
# Epoch 8: saving model to training_1/cp-0008.ckpt
# 39/39 [==============================] - 40s 1s/step - loss: 1.2068 - categorical_accuracy: 0.6647 - val_loss: 1.3598 - val_categorical_accuracy: 0.6090
# Epoch 9/20
# 39/39 [==============================] - ETA: 0s - loss: 1.0747 - categorical_accuracy: 0.6931
# Epoch 9: saving model to training_1/cp-0009.ckpt
# 39/39 [==============================] - 41s 1s/step - loss: 1.0747 - categorical_accuracy: 0.6931 - val_loss: 1.3275 - val_categorical_accuracy: 0.6185
# Epoch 10/20
# 39/39 [==============================] - ETA: 0s - loss: 1.0346 - categorical_accuracy: 0.7058
# Epoch 10: saving model to training_1/cp-0010.ckpt
# 39/39 [==============================] - 40s 1s/step - loss: 1.0346 - categorical_accuracy: 0.7058 - val_loss: 1.2412 - val_categorical_accuracy: 0.6374
# Epoch 11/20
# 39/39 [==============================] - ETA: 0s - loss: 0.9453 - categorical_accuracy: 0.7449
# Epoch 11: saving model to training_1/cp-0011.ckpt
# 39/39 [==============================] - 41s 1s/step - loss: 0.9453 - categorical_accuracy: 0.7449 - val_loss: 1.2331 - val_categorical_accuracy: 0.6256
# Epoch 12/20
# 39/39 [==============================] - ETA: 0s - loss: 0.9514 - categorical_accuracy: 0.7186
# Epoch 12: saving model to training_1/cp-0012.ckpt
# 39/39 [==============================] - 40s 1s/step - loss: 0.9514 - categorical_accuracy: 0.7186 - val_loss: 1.2091 - val_categorical_accuracy: 0.6445
# Epoch 13/20
# 39/39 [==============================] - ETA: 0s - loss: 0.9422 - categorical_accuracy: 0.7190
# Epoch 13: saving model to training_1/cp-0013.ckpt
# 39/39 [==============================] - 40s 1s/step - loss: 0.9422 - categorical_accuracy: 0.7190 - val_loss: 1.1735 - val_categorical_accuracy: 0.6422
# Epoch 14/20
# 39/39 [==============================] - ETA: 0s - loss: 0.8527 - categorical_accuracy: 0.7395
# Epoch 14: saving model to training_1/cp-0014.ckpt
# 39/39 [==============================] - 40s 1s/step - loss: 0.8527 - categorical_accuracy: 0.7395 - val_loss: 1.1551 - val_categorical_accuracy: 0.6564
# Epoch 15/20
# 39/39 [==============================] - ETA: 0s - loss: 0.8306 - categorical_accuracy: 0.7560
# Epoch 15: saving model to training_1/cp-0015.ckpt
# 39/39 [==============================] - 40s 1s/step - loss: 0.8306 - categorical_accuracy: 0.7560 - val_loss: 1.1637 - val_categorical_accuracy: 0.6161
# Epoch 16/20
# 39/39 [==============================] - ETA: 0s - loss: 0.8661 - categorical_accuracy: 0.7424
# Epoch 16: saving model to training_1/cp-0016.ckpt
# 39/39 [==============================] - 41s 1s/step - loss: 0.8661 - categorical_accuracy: 0.7424 - val_loss: 1.1746 - val_categorical_accuracy: 0.6185
# Epoch 17/20
# 39/39 [==============================] - ETA: 0s - loss: 0.7831 - categorical_accuracy: 0.7555
# Epoch 17: saving model to training_1/cp-0017.ckpt
# 39/39 [==============================] - 40s 1s/step - loss: 0.7831 - categorical_accuracy: 0.7555 - val_loss: 1.1163 - val_categorical_accuracy: 0.6706
# Epoch 18/20
# 39/39 [==============================] - ETA: 0s - loss: 0.7485 - categorical_accuracy: 0.7765
# Epoch 18: saving model to training_1/cp-0018.ckpt
# 39/39 [==============================] - 40s 1s/step - loss: 0.7485 - categorical_accuracy: 0.7765 - val_loss: 1.1192 - val_categorical_accuracy: 0.6730
# Epoch 19/20
# 39/39 [==============================] - ETA: 0s - loss: 0.7360 - categorical_accuracy: 0.7773
# Epoch 19: saving model to training_1/cp-0019.ckpt
# 39/39 [==============================] - 40s 1s/step - loss: 0.7360 - categorical_accuracy: 0.7773 - val_loss: 1.1304 - val_categorical_accuracy: 0.6611
# Epoch 20/20
# 20/39 [==============>...............] - ETA: 19s - loss: 0.7173 - categorical_accuracy: 0.7867

# %%
latest = tf.train.latest_checkpoint('training_1')
latest #filename of the latest checkpoint
# Out:
# 'training_1/cp-0020.ckpt'

# %%
valcheckgen = val_datagen.flow_from_directory(val_dir,
                                                    batch_size=64,
                                                    class_mode='categorical',
                                                    target_size=(224,224),
                                                    keep_aspect_ratio=False,
                                                    classes=gem_types_list,
                                                    shuffle=False) 

true_classes=valcheckgen.classes

model_1.load_weights(latest)

val_preds  = model_1.predict(valcheckgen)

val_pred_classes=np.argmax(val_preds,axis=1)

print(len(true_classes),len(val_pred_classes))

print(np.sum(true_classes==val_pred_classes))
# Out:
# Found 422 images belonging to 87 classes.
# 7/7 [==============================] - 2s 264ms/step
# 422 422
# 275

# %%
from sklearn.metrics._plot.regression import check_random_state
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Get the names of the ten classes
class_names = val_generator.class_indices.keys()

def plot_heatmap(y_true, y_pred, class_names, ax, title):
    cm = confusion_matrix(y_true, y_pred)

    cm_diag = np.diagonal(cm)

    indices=np.argsort(cm_diag)[:][::-1]

    cm_s = cm[indices,:]
    cm_s = cm_s[:,indices]

    print(cm_s.shape)

    sns.heatmap(
        cm_s, 
        annot=False, 
        square=True, 
        xticklabels=indices, 
        yticklabels=indices,
        fmt='d', 
        cmap=plt.cm.Blues,
        cbar=False,
        ax=ax
    )
    ax.set_title(title, fontsize=16)
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right")
    ax.set_ylabel('True Label', fontsize=12)
    ax.set_xlabel('Predicted Label', fontsize=12)

fig, ax1 = plt.subplots(1, 1, figsize=(10, 10))

plot_heatmap(true_classes, val_pred_classes, class_names, ax1, title="DenseNet121")    

plt.show()
# Out:
# (87, 87)
